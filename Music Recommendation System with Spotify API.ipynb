# %%
import requests
import base64

# Replace with your own Client ID and Client Secret
CLIENT_ID = 'bb6713a9985247af9895a58f5e93ab78'
CLIENT_SECRET = '7821ff8570b54f949b75e3eef85712b9'

# Base64 encode the client ID and client secret
client_credentials = f"{CLIENT_ID}:{CLIENT_SECRET}"
client_credentials_base64 = base64.b64encode(client_credentials.encode())

# Request the access token
token_url = 'https://accounts.spotify.com/api/token'
headers = {
    'Authorization': f'Basic {client_credentials_base64.decode()}'
}
data = {
    'grant_type': 'client_credentials'
}
response = requests.post(token_url, data=data, headers=headers)

if response.status_code == 200:
    access_token = response.json()['access_token']
    print("Access token obtained successfully.")
else:
    print("Error obtaining access token.")
    exit()
# Out:
# Access token obtained successfully.

# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in c:\users\madhu\anaconda3\lib\site-packages (2.23.0)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\madhu\anaconda3\lib\site-packages (from spotipy) (1.26.14)
# Requirement already satisfied: redis>=3.5.3 in c:\users\madhu\anaconda3\lib\site-packages (from spotipy) (4.6.0)
# Requirement already satisfied: six>=1.15.0 in c:\users\madhu\anaconda3\lib\site-packages (from spotipy) (1.16.0)
# Requirement already satisfied: requests>=2.25.0 in c:\users\madhu\anaconda3\lib\site-packages (from spotipy) (2.28.1)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\madhu\anaconda3\lib\site-packages (from redis>=3.5.3->spotipy) (4.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madhu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\madhu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madhu\anaconda3\lib\site-packages (from requests>=2.25.0->spotipy) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth

def get_trending_playlist_data(playlist_id, access_token):
    # Set up Spotipy with the access token
    sp = spotipy.Spotify(auth=access_token)

    # Get the tracks from the playlist
    playlist_tracks = sp.playlist_tracks(playlist_id, fields='items(track(id, name, artists, album(id, name)))')

    # Extract relevant information and store in a list of dictionaries
    music_data = []
    for track_info in playlist_tracks['items']:
        track = track_info['track']
        track_name = track['name']
        artists = ', '.join([artist['name'] for artist in track['artists']])
        album_name = track['album']['name']
        album_id = track['album']['id']
        track_id = track['id']

        # Get audio features for the track
        audio_features = sp.audio_features(track_id)[0] if track_id != 'Not available' else None

        # Get release date of the album
        try:
            album_info = sp.album(album_id) if album_id != 'Not available' else None
            release_date = album_info['release_date'] if album_info else None
        except:
            release_date = None

        # Get popularity of the track
        try:
            track_info = sp.track(track_id) if track_id != 'Not available' else None
            popularity = track_info['popularity'] if track_info else None
        except:
            popularity = None

        # Add additional track information to the track data
        track_data = {
            'Track Name': track_name,
            'Artists': artists,
            'Album Name': album_name,
            'Album ID': album_id,
            'Track ID': track_id,
            'Popularity': popularity,
            'Release Date': release_date,
            'Duration (ms)': audio_features['duration_ms'] if audio_features else None,
            'Explicit': track_info.get('explicit', None),
            'External URLs': track_info.get('external_urls', {}).get('spotify', None),
            'Danceability': audio_features['danceability'] if audio_features else None,
            'Energy': audio_features['energy'] if audio_features else None,
            'Key': audio_features['key'] if audio_features else None,
            'Loudness': audio_features['loudness'] if audio_features else None,
            'Mode': audio_features['mode'] if audio_features else None,
            'Speechiness': audio_features['speechiness'] if audio_features else None,
            'Acousticness': audio_features['acousticness'] if audio_features else None,
            'Instrumentalness': audio_features['instrumentalness'] if audio_features else None,
            'Liveness': audio_features['liveness'] if audio_features else None,
            'Valence': audio_features['valence'] if audio_features else None,
            'Tempo': audio_features['tempo'] if audio_features else None,
            # Add more attributes as needed
        }

        music_data.append(track_data)

    # Create a pandas DataFrame from the list of dictionaries
    df = pd.DataFrame(music_data)

    return df

# %%
playlist_id = '1rjEWACti8MY56kR9gWq4Q'

# Call the function to get the music data from the playlist and store it in a DataFrame
music_df = get_trending_playlist_data(playlist_id, access_token)

# Display the DataFrame
print(music_df)
# Out:
#                                       Track Name  \
# 0                              Agar Tum Saath Ho
# 1                                         Shayad
# 2                 Kaise Hua (From "Kabir Singh")
# 3                                         Kabira
# 4                      Ranjha (From "Shershaah")
# 5                                   Kun Faya Kun
# 6   Tujhe Kitna Chahne Lage (From "Kabir Singh")
# 7                  Tum Hi Ho (From "Aashiqui 2")
# 8                   Yaen Ennai Pirindhaai - Male
# 9                                          Uyire
# 10                   Ik Vaari Aa (From "Raabta")
# 11           Raataan Lambiyan (From "Shershaah")
# 12           Kadhaippoma (From "Oh My Kadavule")
# 13                Bekhayali (From "Kabir Singh")
# 14                                Ishq Wala Love
# 15                                        Malare
# 16                               Kabira (Encore)
# 17                                         Neeve
# 18                         Nuvvunte Naa Jathagaa
# 19                                   Life Of Ram
# 20               Kadalalle (From "Dear Comrade")
# 21                 Chitti (From "Jathi Ratnalu")
# 22                                   Chiru Chiru
# 23                               Kola Kalle Ilaa
# 24    Ninnu Chuse Anandamlo (From "Gang Leader")
# 25                                   Asha Pasham
# 26                                        Yemito
# 27                  Telisiney Na Nuvvey - Telugu
# 28                          Emitemitemo - Telugu
# 29                             Kailove Chedugudu
# 30                              Nee Yadalo Naaku
# 31                            Monna Kanipinchavu
# 32          Arerey Manasa (From "Falaknuma Das")
# 33                                     Yetu Pone
#
#                                               Artists  \
# 0                           Alka Yagnik, Arijit Singh
# 1                                Pritam, Arijit Singh
# 2                                       Vishal Mishra
# 3                 Pritam, Tochi Raina, Rekha Bhardwaj
# 4           Jasleen Royal, B Praak, Romy, Anvita Dutt
# 5               A.R. Rahman, Javed Ali, Mohit Chauhan
# 6                               Arijit Singh, Mithoon
# 7                                        Arijit Singh
# 8             Sid Sriram, Dhruv Vikram, Banita Sandhu
# 9                             Sid Sriram, Ankit Menon
# 10                               Pritam, Arijit Singh
# 11         Tanishk Bagchi, Jubin Nautiyal, Asees Kaur
# 12                             Leon James, Sid Sriram
# 13                    Sachet Tandon, Sachet-Parampara
# 14  Vishal-Shekhar, Salim Merchant, Neeti Mohan, S...
# 15                    Vijay Yesudas, Rajesh Murugesan
# 16               Pritam, Harshdeep Kaur, Arijit Singh
# 17                                        Yazin Nizar
# 18           A.R. Rahman, Sid Sriram, Issrath Quadhri
# 19                                      Pradeep Kumar
# 20  Sid Sriram, Aishwarya Ravichandran, Justin Pra...
# 21                               Ram Miriyala, Radhan
# 22        Yuvan Shankar Raja, Haricharan, Sagar Desai
# 23                                         Sid Sriram
# 24                    Anirudh Ravichander, Sid Sriram
# 25                                    Anurag Kulkarni
# 26                                         Haricharan
# 27                              L. V. Revanth, Radhan
# 28                                   Alphonse, Radhan
# 29        Naveen, S.P. Charan, S. P. Balasubrahmanyam
# 30                    Yuvan Shankar Raja, Sagar Desai
# 31          Harris Jayaraj, Naresh Iyer, Prashanthini
# 32                                         Sid Sriram
# 33                                      Kala Bhairava
#
#                                            Album Name                Album ID  \
# 0                                             Tamasha  2CUXo26JAWIbQx0EVMnjpA
# 1   Love Aaj Kal (Original Motion Picture Soundtrack)  6IXfWhC7omotM4lt0ROmEr
# 2                      Kaise Hua (From "Kabir Singh")  1ncyKqyZae6DoyjYaV9LmS
# 3                             Yeh Jawaani Hai Deewani  2Lxoc72vRTGdQfMvj7Ovi1
# 4                           Ranjha (From "Shershaah")  0Z1zYMwJRpvq0d9rdqTOYo
# 5                                            Rockstar  3RZxrS2dDZlbsYtMRM89v8
# 6        Tujhe Kitna Chahne Lage (From "Kabir Singh")  3I8PdIhk6pNm8Kv0HiF14V
# 7                  Ultimate Love Songs - Arijit Singh  1WwkojG9sjMSrFVz4D51W0
# 8                                       Adithya Varma  3IvKduSq7d2SnZiwxA7hJK
# 9                   Uyire (From "Gauthamante Radham")  0dCwYrUoJ5HynQ1L9DcFAw
# 10                        Ik Vaari Aa (From "Raabta")  3rJorGgrI3Vr2oL06qCzfd
# 11                Raataan Lambiyan (From "Shershaah")  2DKSZvMj7Da6rzNVPMgREj
# 12                Kadhaippoma (From "Oh My Kadavule")  0XEhNGVpjOxDoi8ByFyPFR
# 13                     Bekhayali (From "Kabir Singh")  5m5aIc0rrrPUMDARDnQzB9
# 14  Student of the Year (Original Motion Picture S...  1Q9pYTcpVfz0eJTZZczELy
# 15                                             Premam  5gkkfFiedjuYeCM0v4IlZu
# 16                            Yeh Jawaani Hai Deewani  2Lxoc72vRTGdQfMvj7Ovi1
# 17                                              Neeve  2m9VqOtsGbywuyl4QXp32V
# 18  I - Manoharudu (Original Motion Picture Soundt...  0PqDwbg5QiH6S0uZTPWJR8
# 19                                              Jaanu  76Gn7WA0mvH8Ke4yjGlveG
# 20                    Kadalalle (From "Dear Comrade")  6h1bvW0kjAphZefD1rXfZM
# 21                      Chitti (From "Jathi Ratnalu")  3vcbeHMefvNcmt3UWddxe8
# 22        Awaara (Original Motion Picture Soundtrack)  0UKhCWkRL6X4Kwbjz8Pf0q
# 23                                   Varudu Kaavalenu  18unuuoBX06HULexKqMA7F
# 24         Ninnu Chuse Anandamlo (From "Gang Leader")  6LsiFF3CU5YKaHmNg60pWB
# 25                              Care Of Kancharapalem  6oD7OKpTjFwqh7RsgUE38p
# 26  Andala Rakshasi (Original Motion Picture Sound...  2pAVF1q5XzPoDy2yINgOjg
# 27                                        Arjun Reddy  0nILDmaLegcCu7G3GzVWci
# 28                                        Arjun Reddy  0nILDmaLegcCu7G3GzVWci
# 29                                              Sakhi  0x25Nwzk4BVwlUaZq5Hczu
# 30        Awaara (Original Motion Picture Soundtrack)  0UKhCWkRL6X4Kwbjz8Pf0q
# 31  Surya S/o Krishnan (Original Motion Picture So...  34EFScbYAJkSTujfbtT8gO
# 32               Arerey Manasa (From "Falaknuma Das")  4cAqcskezsUVZjD01vl4Po
# 33                                       Dear Comrade  2Dm5RqMxec1kI17G2awogs
#
#                   Track ID  Popularity Release Date  Duration (ms)  Explicit  \
# 0   3hkC9EHFZNQPXrtl8WPHnX          79   2015-10-16         341055     False
# 1   1smFN2CLqGROu0J0UyvDfL          79   2020-02-14         247941     False
# 2   1y1rQTkWmrZdJmjwuK07GC          76   2019-06-13         234722     False
# 3   4bD9z9qa4qg9BhryvYWB7c          79   2013-03-30         223460     False
# 4   72zHuDxFQTjbL51qJQSA7j          80   2021-08-05         228855     False
# 5   7F8RNvTQlvbeBLeenycvN6          69   2011-10-01         470500     False
# 6   2Fv2injs4qAm8mJBGaxVKU          77   2019-05-31         284780     False
# 7   7ouBSPZKQpm7zQz2leJXta          70   2020-05-19         261974     False
# 8   2GYzXSeNa3Y0BfIfS1VJj3          72   2019-10-22         198250     False
# 9   6kPYrnBJubso1t47lbXvNU          65   2020-01-20         199922     False
# 10  5lrA2NzUxmBjKr2tCZfMtl          65   2017-04-21         274687     False
# 11  2rOnSn2piaqLAlYjtfUBlY          79   2021-07-30         230292     False
# 12  5cfKBuE5XKtlaNOVjQwA9H          71   2020-01-03         282208     False
# 13  1feANd8EfcDP5UqSvbheM3          71   2019-05-24         371791     False
# 14  1hQia6rxgfM1ly2hE3StWp          75   2012-08-31         257973     False
# 15  4Hvf9xIeJWp5p9FkJerQhN          62   2015-03-25         316552     False
# 16  3jJ5HgLRNydtLRghjWVaCG          64   2013-03-30         270439     False
# 17  5NObORkzAytZ9tmAyGXaRP          60   2016-10-21         307336     False
# 18  5dG3KI5rIUwiUQNNr3Y1to          65   2014-12-30         352613     False
# 19  0i5KYCaQs1xY7z9MWCFoXW          62   2020-01-21         364375     False
# 20  2kW6AMK99mnEO6X01r2E3T          59   2019-05-15         260992     False
# 21  6Z40IRipd6pNcUULY6SXng          64   2021-01-11         184128     False
# 22  6O1VWYPfl85dDeKiaCJKza          65   2010-04-10         284467     False
# 23  7GfyeCjPx05EUlAfMksojh          53   2021-02-14         223387     False
# 24  7FMvOZMzbhKWBvwNCOByvc          51   2019-09-03         293000     False
# 25  1lrgvbZzsjatMee0Uk8o0P          60   2018-08-20         260000     False
# 26  1eknwgCfzOXC0VRTst91l7          63   2012-06-02         268826     False
# 27  0tuK3bLfUyMwQeh6nxT91F          57   2017-08-22         252287     False
# 28  59enSWdv8N3wMkTbNJ6Y3m          43   2017-08-22         203250     False
# 29  6XbkcFDeIoyIOe2HWoAxBh          60   2000-12-31         278307     False
# 30  4wUOdPcYoqYZGM2wSdoLQu          63   2010-04-10         292827     False
# 31  4rc1WGmRJ2CsHXTmrBu3gH          57   2008-10-31         332013     False
# 32  61fXT6uwJ2THPkbmxa65OI          62   2019-05-02         301500     False
# 33  5bf5PpAQmxCbXBcRQa5R3C          64   2019-07-23         249023     False
#
#                                         External URLs  ...  Energy  Key  \
# 0   https://open.spotify.com/track/3hkC9EHFZNQPXrt...  ...   0.519    3
# 1   https://open.spotify.com/track/1smFN2CLqGROu0J...  ...   0.468    8
# 2   https://open.spotify.com/track/1y1rQTkWmrZdJmj...  ...   0.464    2
# 3   https://open.spotify.com/track/4bD9z9qa4qg9Bhr...  ...   0.555    2
# 4   https://open.spotify.com/track/72zHuDxFQTjbL51...  ...   0.573    1
# 5   https://open.spotify.com/track/7F8RNvTQlvbeBLe...  ...   0.378    1
# 6   https://open.spotify.com/track/2Fv2injs4qAm8mJ...  ...   0.396   11
# 7   https://open.spotify.com/track/7ouBSPZKQpm7zQz...  ...   0.451    5
# 8   https://open.spotify.com/track/2GYzXSeNa3Y0BfI...  ...   0.432    1
# 9   https://open.spotify.com/track/6kPYrnBJubso1t4...  ...   0.474    6
# 10  https://open.spotify.com/track/5lrA2NzUxmBjKr2...  ...   0.752    4
# 11  https://open.spotify.com/track/2rOnSn2piaqLAlY...  ...   0.630   10
# 12  https://open.spotify.com/track/5cfKBuE5XKtlaNO...  ...   0.577    7
# 13  https://open.spotify.com/track/1feANd8EfcDP5Uq...  ...   0.585    9
# 14  https://open.spotify.com/track/1hQia6rxgfM1ly2...  ...   0.295    0
# 15  https://open.spotify.com/track/4Hvf9xIeJWp5p9F...  ...   0.501   11
# 16  https://open.spotify.com/track/3jJ5HgLRNydtLRg...  ...   0.612    2
# 17  https://open.spotify.com/track/5NObORkzAytZ9tm...  ...   0.713    9
# 18  https://open.spotify.com/track/5dG3KI5rIUwiUQN...  ...   0.686    0
# 19  https://open.spotify.com/track/0i5KYCaQs1xY7z9...  ...   0.559    4
# 20  https://open.spotify.com/track/2kW6AMK99mnEO6X...  ...   0.296    7
# 21  https://open.spotify.com/track/6Z40IRipd6pNcUU...  ...   0.679    7
# 22  https://open.spotify.com/track/6O1VWYPfl85dDeK...  ...   0.496    7
# 23  https://open.spotify.com/track/7GfyeCjPx05EUlA...  ...   0.359    5
# 24  https://open.spotify.com/track/7FMvOZMzbhKWBvw...  ...   0.730    5
# 25  https://open.spotify.com/track/1lrgvbZzsjatMee...  ...   0.439    3
# 26  https://open.spotify.com/track/1eknwgCfzOXC0VR...  ...   0.480    0
# 27  https://open.spotify.com/track/0tuK3bLfUyMwQeh...  ...   0.431    5
# 28  https://open.spotify.com/track/59enSWdv8N3wMkT...  ...   0.526    4
# 29  https://open.spotify.com/track/6XbkcFDeIoyIOe2...  ...   0.252    5
# 30  https://open.spotify.com/track/4wUOdPcYoqYZGM2...  ...   0.363    0
# 31  https://open.spotify.com/track/4rc1WGmRJ2CsHXT...  ...   0.587    6
# 32  https://open.spotify.com/track/61fXT6uwJ2THPkb...  ...   0.550    2
# 33  https://open.spotify.com/track/5bf5PpAQmxCbXBc...  ...   0.764    0
#
#     Loudness  Mode  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 0     -8.744     1       0.0326       0.55700          0.000268    0.1720
# 1     -7.642     1       0.0341       0.78400          0.000000    0.1520
# 2     -6.975     1       0.0404       0.45200          0.000000    0.1090
# 3     -6.861     1       0.0271       0.48100          0.000000    0.1920
# 4     -5.843     1       0.0502       0.47800          0.000000    0.0971
# 5    -11.008     1       0.0329       0.67900          0.000000    0.0910
# 6     -7.556     1       0.0366       0.73600          0.000000    0.1100
# 7     -6.250     0       0.0250       0.78800          0.000000    0.1220
# 8     -7.862     1       0.0278       0.81800          0.000008    0.1190
# 9     -8.510     0       0.0550       0.65000          0.000002    0.1020
# 10    -4.857     0       0.0534       0.30500          0.000000    0.7080
# 11    -5.549     1       0.0413       0.61500          0.000000    0.1080
# 12    -6.674     1       0.0432       0.45100          0.000004    0.2640
# 13    -5.180     0       0.0428       0.45000          0.000000    0.3190
# 14   -12.377     0       0.0334       0.53400          0.000045    0.0782
# 15   -10.841     1       0.0300       0.75200          0.000012    0.1080
# 16    -7.978     1       0.1140       0.44100          0.000000    0.1800
# 17    -6.405     0       0.0443       0.05200          0.000000    0.0759
# 18    -4.111     1       0.0361       0.12600          0.000000    0.1470
# 19    -8.829     0       0.0508       0.21000          0.000118    0.1160
# 20    -9.379     1       0.0257       0.84800          0.000001    0.2090
# 21    -7.239     1       0.5360       0.24600          0.000000    0.0835
# 22    -7.554     0       0.0327       0.22300          0.000507    0.1030
# 23   -10.960     1       0.0380       0.68400          0.000002    0.0775
# 24    -5.010     0       0.0488       0.24500          0.000017    0.1160
# 25    -8.204     1       0.0413       0.80300          0.000000    0.1980
# 26    -8.435     0       0.0554       0.13400          0.000000    0.2600
# 27    -6.260     0       0.0357       0.58100          0.000000    0.1110
# 28    -4.886     1       0.0286       0.50100          0.000000    0.1190
# 29   -20.410     0       0.0525       0.00459          0.000000    0.1110
# 30    -6.691     0       0.0330       0.03010          0.060900    0.1100
# 31    -7.383     0       0.2230       0.30400          0.000000    0.0693
# 32    -7.417     0       0.0352       0.36500          0.000337    0.1090
# 33    -6.364     1       0.0429       0.10400          0.000001    0.1480
#
#     Valence    Tempo
# 0     0.415  122.925
# 1     0.319  135.875
# 2     0.150  137.839
# 3     0.191   84.027
# 4     0.236   82.941
# 5     0.575   87.549
# 6     0.306   70.368
# 7     0.309   94.054
# 8     0.348   76.499
# 9     0.186   78.768
# 10    0.428  127.965
# 11    0.512   81.009
# 12    0.157   90.012
# 13    0.345  171.843
# 14    0.694  135.041
# 15    0.544   82.525
# 16    0.898  171.841
# 17    0.297  129.911
# 18    0.208   78.973
# 19    0.388   90.009
# 20    0.502   97.902
# 21    0.838  208.196
# 22    0.645   92.007
# 23    0.606  169.883
# 24    0.407  139.948
# 25    0.531  179.474
# 26    0.449  133.986
# 27    0.396  183.106
# 28    0.349  135.883
# 29    0.320   87.987
# 30    0.454  105.034
# 31    0.584   96.921
# 32    0.423   89.121
# 33    0.222  139.911
#
# [34 rows x 21 columns]

# %%
print(music_df.isnull().sum())
# Out:
# Track Name          0
# Artists             0
# Album Name          0
# Album ID            0
# Track ID            0
# Popularity          0
# Release Date        0
# Duration (ms)       0
# Explicit            0
# External URLs       0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Mode                0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# dtype: int64

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime
from sklearn.metrics.pairwise import cosine_similarity

data = music_df

# %%
# Function to calculate weighted popularity scores based on release date
def calculate_weighted_popularity(release_date):
    # Convert the release date to datetime object
    release_date = datetime.strptime(release_date, '%Y-%m-%d')

    # Calculate the time span between release date and today's date
    time_span = datetime.now() - release_date

    # Calculate the weighted popularity score based on time span (e.g., more recent releases have higher weight)
    weight = 1 / (time_span.days + 1)
    return weight

# %%
# Normalize the music features using Min-Max scaling
scaler = MinMaxScaler()
music_features = music_df[['Danceability', 'Energy', 'Key', 
                           'Loudness', 'Mode', 'Speechiness', 'Acousticness',
                           'Instrumentalness', 'Liveness', 'Valence', 'Tempo']].values
music_features_scaled = scaler.fit_transform(music_features)

# %%
# a function to get content-based recommendations based on music features
def content_based_recommendations(input_song_name, num_recommendations=5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    # Get the index of the input song in the music DataFrame
    input_song_index = music_df[music_df['Track Name'] == input_song_name].index[0]

    # Calculate the similarity scores based on music features (cosine similarity)
    similarity_scores = cosine_similarity([music_features_scaled[input_song_index]], music_features_scaled)

    # Get the indices of the most similar songs
    similar_song_indices = similarity_scores.argsort()[0][::-1][1:num_recommendations + 1]

    # Get the names of the most similar songs based on content-based filtering
    content_based_recommendations = music_df.iloc[similar_song_indices][['Track Name', 'Artists', 'Album Name', 'Release Date', 'Popularity']]

    return content_based_recommendations

# %%
# a function to get hybrid recommendations based on weighted popularity
def hybrid_recommendations(input_song_name, num_recommendations=5, alpha=0.5):
    if input_song_name not in music_df['Track Name'].values:
        print(f"'{input_song_name}' not found in the dataset. Please enter a valid song name.")
        return

    # Get content-based recommendations
    content_based_rec = content_based_recommendations(input_song_name, num_recommendations)

    # Get the popularity score of the input song
    popularity_score = music_df.loc[music_df['Track Name'] == input_song_name, 'Popularity'].values[0]

    # Calculate the weighted popularity score
    weighted_popularity_score = popularity_score * calculate_weighted_popularity(music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0])

    # Combine content-based and popularity-based recommendations based on weighted popularity
    hybrid_recommendations = content_based_rec
    hybrid_recommendations = hybrid_recommendations.append({
        'Track Name': input_song_name,
        'Artists': music_df.loc[music_df['Track Name'] == input_song_name, 'Artists'].values[0],
        'Album Name': music_df.loc[music_df['Track Name'] == input_song_name, 'Album Name'].values[0],
        'Release Date': music_df.loc[music_df['Track Name'] == input_song_name, 'Release Date'].values[0],
        'Popularity': weighted_popularity_score
    }, ignore_index=True)

    # Sort the hybrid recommendations based on weighted popularity score
    hybrid_recommendations = hybrid_recommendations.sort_values(by='Popularity', ascending=False)

    # Remove the input song from the recommendations
    hybrid_recommendations = hybrid_recommendations[hybrid_recommendations['Track Name'] != input_song_name]


    return hybrid_recommendations

# %%
input_song_name = "Yetu Pone"
recommendations = hybrid_recommendations(input_song_name, num_recommendations=2)
print(f"Hybrid recommended songs for '{input_song_name}':")
print(recommendations)
# Out:
# Hybrid recommended songs for 'Yetu Pone':
#                   Track Name                                    Artists  \
# 1  Ranjha (From "Shershaah")  Jasleen Royal, B Praak, Romy, Anvita Dutt
# 0      Nuvvunte Naa Jathagaa   A.R. Rahman, Sid Sriram, Issrath Quadhri
#
#                                           Album Name Release Date  Popularity
# 1                          Ranjha (From "Shershaah")   2021-08-05        80.0
# 0  I - Manoharudu (Original Motion Picture Soundt...   2014-12-30        65.0
# C:\Users\madhu\AppData\Local\Temp\ipykernel_4356\209674984.py:18: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   hybrid_recommendations = hybrid_recommendations.append({
